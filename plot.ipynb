# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = {1: 0.0,
 2: 0.23809523809523808,
 3: 0.0,
 4: 0.3148148148148148,
 5: 0.4,
 6: 0.3684210526315789,
 7: 0.35294117647058826,
 8: 0.0,
 9: 0.42857142857142855,
 10: 0.5,
 15: 0.58,
 20: 0.6206896551724138,
 25: 1.0,
 30: 1.0,
 35: 1.0,
 40: 1.0}

# %%
b = {1: 0.25541257100718706,
 2: 0.29880214636922364,
 3: 0.07886594385808866,
 4: 0.37460697670622567,
 5: 0.20521206295800484,
 6: 0.36681059857600645,
 7: 0.35612951001423176,
 8: 0.05957624228825877,
 9: 0.25921178232522335,
 10: 0.3241612855549327,
 15: 0.29765503817268696,
 20: 0.3368005162182266,
 25: 0.3368005162182266,
 30: 0.3368005162182266,
 35: 0.3368005162182266,
 40: 0.3368005162182266}

# %%
sns.set_style("darkgrid")
sns.lineplot(a, marker='o', color="blue")
plt.xlabel("retrieved chunks")
plt.ylabel("faithfulness")
plt.title("Faithfulness over retrieved chunk count")
# Out:
# Text(0.5, 1.0, 'Faithfulness over retrived chunk count')

# %%
sns.set_style("darkgrid")
sns.lineplot(b, marker='o', color="orange")
plt.xlabel("retrieved chunks")
plt.ylabel("answer relevance")
plt.title("Answer relevance over retrieved chunk count")
# Out:
# Text(0.5, 1.0, 'Answer relevance over retrieved chunk count')
